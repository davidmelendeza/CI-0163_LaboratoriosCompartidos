# %% [markdown]
# # Laboratorio #11: Segmentación
#
# ### Integrantes:
# - David Meléndez Aguilar
#
# - Sebastián Venegas Brenes

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler


# Cargar datasets como archivos .csv
df_lunas = pd.read_csv('lunas.csv')
df_clusters = pd.read_csv('clusters_dispersos.csv')
df_circulos = pd.read_csv('circulos_concentricos.csv')

#Visualizacion de los datos
df_lunas.head()
# df_clusters.head()
# df_circulos.head()
# Out:
#    Feature1  Feature2
# 0  0.622519 -0.372101
# 1  1.904269 -0.136303
# 2 -0.069431  0.456117
# 3  0.933899  0.237483
# 4  1.180360 -0.490847

# %% [markdown]
# ## Dataset de Lunas

# %% [markdown]
# ### DBScan

# %%
# Escalamiento
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_lunas)

# Aplicar DBScan
dbscan = DBSCAN(eps=0.3, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

# Agregar etiquetas al DataFrame
df_lunas['Cluster'] = clusters

# Visualizar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(df_lunas['Feature1'], df_lunas['Feature2'], c=df_lunas['Cluster'], cmap='viridis', s=50)
plt.title('Clusters generados por DBSCAN')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.grid(True)
plt.show()

# Ver cuántos clusters encontró (incluyendo -1 para ruido)
print(df_lunas['Cluster'].value_counts().sort_index())
# Out:
# Cluster
# 0    150
# 1    150
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset de Clusters Dispersos

# %% [markdown]
# ### DBScan

# %%
# Escalamiento
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_clusters)

# Aplicar DBScan
dbscan = DBSCAN(eps=0.3, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

# Agregar etiquetas al DataFrame
df_clusters['Cluster'] = clusters

# Visualizar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(df_clusters['Feature1'], df_clusters['Feature2'], c=df_clusters['Cluster'], cmap='viridis', s=50)
plt.title('Clusters generados por DBSCAN')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.grid(True)
plt.show()

# Ver cuántos clusters encontró (incluyendo -1 para ruido)
print(df_clusters['Cluster'].value_counts().sort_index())
# Out:
# Cluster
# 0    100
# 1    100
# 2    100
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset de Circulos Concentricos

# %% [markdown]
# ### DBScan

# %%
# Escalamiento
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_circulos)

# Aplicar DBScan
dbscan = DBSCAN(eps=0.3, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

# Agregar etiquetas al DataFrame
df_circulos['Cluster'] = clusters

# Visualizar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(df_circulos['Feature1'], df_circulos['Feature2'], c=df_circulos['Cluster'], cmap='viridis', s=50)
plt.title('Clusters generados por DBSCAN')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.grid(True)
plt.show()

# Ver cuántos clusters encontró (incluyendo -1 para ruido)
print(df_circulos['Cluster'].value_counts().sort_index())
# Out:
# Cluster
# -1      1
#  0    149
#  1     36
#  2      6
#  3     43
#  4      9
#  5     22
#  6     13
#  7     21
# Name: count, dtype: int64
