# %%
import pandas as pd

# Load the CSV file for the National Nutrition Survey
nutr = pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18  Key Anthropometric Indicators by Sex.csv') 

# Show the first 5 rows
nutr.head()
# Out:
#    Rowid Country  State lgd code              State  Yearcode  \
# 0      1   India               1  Jammu And Kashmir      2018
# 1      2   India               1  Jammu And Kashmir      2018
# 2      3   India               2   Himachal Pradesh      2018
# 3      4   India               2   Himachal Pradesh      2018
# 4      5   India               3             Punjab      2018
#
#                               Year  From year  Gender  \
# 0  Calendar Year (Jan - Dec), 2018       2016  Female
# 1  Calendar Year (Jan - Dec), 2018       2016    Male
# 2  Calendar Year (Jan - Dec), 2018       2016  Female
# 3  Calendar Year (Jan - Dec), 2018       2016    Male
# 4  Calendar Year (Jan - Dec), 2018       2016  Female
#
#    Stunted (height for age) children under the age of 5 years (%)  \
# 0                                               13.8
# 1                                               17.4
# 2                                               23.6
# 3                                               32.7
# 4                                               19.6
#
#    Severely stunted (height for age) children under the age of 5 years (%)  \
# 0                                                5.1
# 1                                                6.7
# 2                                                7.9
# 3                                                5.7
# 4                                                5.1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  \
# 0                                               11.4
# 1                                               15.4
# 2                                               30.8
# 3                                               31.4
# 4                                               18.1
#
#    Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)  \
# 0                                                3.6
# 1                                                6.5
# 2                                               16.2
# 3                                                9.5
# 4                                                2.6
#
#    Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)  \
# 0                                                0.1
# 1                                                5.4
# 2                                                5.8
# 3                                                7.0
# 4                                                1.5
#
#    Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)  \
# 0                                                2.1
# 1                                                6.0
# 2                                               11.5
# 3                                                8.3
# 4                                                2.1
#
#    Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# 0                                                7.9
# 1                                               12.1
# 2                                                3.7
# 3                                               12.0
# 4                                                6.9
#
#    Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# 0                                                9.3
# 1                                                4.4
# 2                                                2.2
# 3                                                3.6
# 4                                                6.3
#
#    Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# 0                                                8.5
# 1                                                8.7
# 2                                                3.1
# 3                                                7.9
# 4                                                6.6
#
#    Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# 0                                                1.3
# 1                                                2.1
# 2                                                1.2
# 3                                                1.7
# 4                                                2.8
#
#    Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# 0                                                2.1
# 1                                                1.1
# 2                                                0.2
# 3                                                1.3
# 4                                                2.0
#
#    Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)
# 0                                                1.6
# 1                                                1.6
# 2                                                0.8
# 3                                                1.5
# 4                                                2.4
#
# [5 rows x 44 columns]
